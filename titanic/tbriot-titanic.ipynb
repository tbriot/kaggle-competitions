# %% [markdown]
# # Data exploration

# %%
from datetime import datetime
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split


DATA_DIR = "./data"
MODEL_DIR = "./models"
CSV_FILE_TRAIN = DATA_DIR + "/train.csv"
CSV_FILE_TEST = DATA_DIR + "/test.csv"

df = pd.read_csv(CSV_FILE_TRAIN)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Is Sex a factor in the survival rate ?

# %%
#  Sex statistics
missing = df['Sex'].isnull().sum()
print(f"Number of null value is {missing}")
# Out:
# Number of null value is 0

# %%
# Sex distribution
df.groupby('Sex')['PassengerId'].count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
# Survival rate per sex
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# Conclusion: females have a 74% survival rate, while males have a 18% survival rate.

# %% [markdown]
# ## Is socio-economic status (through PClass column) a factor ?

# %%
#  Pclass statistics
missing = df['Pclass'].isna().sum()
mean = df['Pclass'].mean()
std = df['Pclass'].std()
print(f"Number of null value is {missing}")
print(f"Mean is {mean}")
print(f"Standard deviation is {std}")
# Out:
# Number of null value is 0
# Mean is 2.308641975308642
# Standard deviation is 0.836071240977049

# %%
# Pclass distribution
df.groupby('Pclass')['PassengerId'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
# Survival rate per Pclass
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# Conclusion: 1st class has a 62% survival rate while 3rd class has a 24% survival rate

# %% [markdown]
# ## Is age a factor in the survival rate ?

# %%
#  Age statistics
missing = df['Age'].isna().sum()
mean = df['Age'].mean()
std = df['Age'].std()
print(f"Number of missing value is {missing}")
print(f"Mean is {mean}")
print(f"Standard deviation is {std}")
# Out:
# Number of missing value is 177
# Mean is 29.69911764705882
# Standard deviation is 14.526497332334042

# %%
# Age group distribution
def get_age_group(age):
    if age <= 2:
        return '00-02'
    elif age <= 6:
        return '02-06'
    elif age <= 12:
        return '06-12'
    elif age <= 20:
        return '12-20'
    elif age <= 30:
        return '20-30'
    elif age <= 40:
        return '30-40'
    elif age <= 50:
        return '40-50'
    elif age <= 60:
        return '50-60'
    elif age <= 70:
        return '60-70'
    else:
        return '70+'


# Remove records where age is missing
df_with_age = df[df['Age'].notna()]

# Create new 'age_group' column
df['age_group'] = df_with_age['Age'].apply(get_age_group)
df.groupby('age_group')['PassengerId'].count()
# Out:
# age_group
# 00-02     24
# 02-06     23
# 06-12     22
# 12-20    110
# 20-30    230
# 30-40    155
# 40-50     86
# 50-60     42
# 60-70     17
# 70+        5
# Name: PassengerId, dtype: int64

# %%
# Survival rate per age group
df.groupby('age_group')['Survived'].mean()
# Out:
# age_group
# 00-02    0.625000
# 02-06    0.782609
# 06-12    0.318182
# 12-20    0.381818
# 20-30    0.365217
# 30-40    0.445161
# 40-50    0.383721
# 50-60    0.404762
# 60-70    0.235294
# 70+      0.200000
# Name: Survived, dtype: float64

# %% [markdown]
# Conclusions:
#     - children (< 6yo) are more likely to survive
#     - elderly people > 60yo have are less likely to survive
#     - 10-20 yo have a similar survival rate as 20-60

# %% [markdown]
# As a first iteration, a small model could be created with the following features: sex, pclass, age group.

# %% [markdown]
# ## Dealing with missing age information
# - Age is missing for a lot of entries (177 out of 891, i.e. ~20%)
# - We will extrapolate age based on the 'Name' column because it usually contains a title ('Miss', 'Mrs', 'Mr', 'Master, ...)
# - The title is used as a proxy for age. We will assign the mean age for that particular title.

# %%
# Exploring names for children (12 yo) to find patterns in their names
filtered_df = df[df['Age'] < 12]
filtered_df[['Name', 'Age', 'Sex']].sort_values(by='Age', ascending=True).tail(50)
# Out:
#                                                 Name   Age     Sex
# 297                     Allison, Miss. Helen Loraine   2.0  female
# 205                       Strom, Miss. Telma Matilda   2.0  female
# 530                         Quick, Miss. Phyllis May   2.0  female
# 479                         Hirvonen, Miss. Hildur E   2.0  female
# 119                Andersson, Miss. Ellis Anna Maria   2.0  female
# 340                   Navratil, Master. Edmond Roger   2.0    male
# 261                Asplund, Master. Edvin Rojj Felix   3.0    male
# 193                       Navratil, Master. Michel M   3.0    male
# 348           Coutts, Master. William Loch "William"   3.0    male
# 374                       Palsson, Miss. Stina Viola   3.0  female
# 407                   Richards, Master. William Rowe   3.0    male
# 43          Laroche, Miss. Simonne Marie Anne Andree   3.0  female
# 850          Andersson, Master. Sigvard Harald Elias   4.0    male
# 445                        Dodge, Master. Washington   4.0    male
# 184              Kink-Heilmann, Miss. Luise Gretchen   4.0  female
# 63                             Skoog, Master. Harald   4.0    male
# 691                               Karun, Miss. Manca   4.0  female
# 750                                Wells, Miss. Joan   4.0  female
# 618                      Becker, Miss. Marion Louise   4.0  female
# 171                             Rice, Master. Arthur   4.0    male
# 869                  Johnson, Master. Harold Theodor   4.0    male
# 10                   Sandstrom, Miss. Marguerite Rut   4.0  female
# 777                    Emanuel, Miss. Virginia Ethel   5.0  female
# 233                   Asplund, Miss. Lillian Gertrud   5.0  female
# 448                   Baclini, Miss. Marie Catherine   5.0  female
# 58                      West, Miss. Constance Mirium   5.0  female
# 751                              Moor, Master. Meier   6.0    male
# 720                Harper, Miss. Annie Jessie "Nina"   6.0  female
# 813               Andersson, Miss. Ebba Iris Alfrida   6.0  female
# 535                           Hart, Miss. Eva Miriam   7.0  female
# 50                        Panula, Master. Juha Niilo   7.0    male
# 278                               Rice, Master. Eric   7.0    male
# 24                     Palsson, Miss. Torborg Danira   8.0  female
# 237                 Collyer, Miss. Marjorie "Lottie"   8.0  female
# 787                        Rice, Master. George Hugh   8.0    male
# 549                   Davies, Master. John Morgan Jr   8.0    male
# 147                 Ford, Miss. Robina Maggie "Ruby"   9.0  female
# 634                               Skoog, Miss. Mabel   9.0  female
# 182            Asplund, Master. Clarence Gustaf Hugo   9.0    male
# 852                          Boulos, Miss. Nourelain   9.0  female
# 165  Goldsmith, Master. Frank John William "Frankie"   9.0    male
# 480                   Goodwin, Master. Harold Victor   9.0    male
# 489            Coutts, Master. Eden Leslie "Neville"   9.0    male
# 541             Andersson, Miss. Ingeborg Constanzia   9.0  female
# 819                     Skoog, Master. Karl Thorsten  10.0    male
# 419                        Van Impe, Miss. Catharina  10.0  female
# 59                Goodwin, Master. William Frederick  11.0    male
# 802              Carter, Master. William Thornton II  11.0    male
# 731                         Hassan, Mr. Houssein G N  11.0    male
# 542                Andersson, Miss. Sigrid Elisabeth  11.0  female

# %% [markdown]
# Conclusion:
#     - Almost all female children have 'Miss.' in their name
#     - Almost all male children have 'Master.' in their name
#     - Starting age 11, some male are called 'Mr.'

# %%
# Extract title from Name column
def get_name_title(name):
    if any(t in name for t in ['Miss.', 'Mlle.']):
        return 'Miss'
    elif 'Master.' in name:
        return 'Master'
    if any(t in name for t in ['Mrs.', 'Mme.']):
        return 'Mrs'
    if any(t in name for t in ['Mr.', 'Dr.', 'Rev']):
        return 'Mr'
    else:
        return 'Other'


# Create new 'age_group' column
df['title'] = df['Name'].apply(get_name_title)
df.groupby('title')['PassengerId'].count()
# Out:
# title
# Master     40
# Miss      184
# Mr        530
# Mrs       126
# Other      11
# Name: PassengerId, dtype: int64

# %%
# Explore names without titles
df_no_title = df[df['title'] == 'Other']
df_no_title[['Name', 'Age']].sort_values(by='Age')
# Out:
#                                                   Name   Age
# 443                          Reynaldo, Ms. Encarnacion  28.0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  33.0
# 822                    Reuchlin, Jonkheer. John George  38.0
# 30                            Uruchurtu, Don. Manuel E  40.0
# 536                  Butt, Major. Archibald Willingham  45.0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  48.0
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")  49.0
# 449                     Peuchen, Major. Arthur Godfrey  52.0
# 647                Simonius-Blumer, Col. Oberst Alfons  56.0
# 694                                    Weir, Col. John  60.0
# 745                       Crosby, Capt. Edward Gifford  70.0

# %% [markdown]
# Conclusion:
# - those 11 passengers are considered edge cases, and age is provided for all of them anyways

# %%
# Compute median age by title
df_median_title_age = df.groupby('title', as_index=False)['Age'].median()
df_median_title_age
# Out:
#     title   Age
# 0  Master   3.5
# 1    Miss  21.0
# 2      Mr  30.0
# 3     Mrs  35.0
# 4   Other  48.0

# %%
# Creating dictionary mapping titles to median ages
title_age_map = dict(zip(df_median_title_age['title'], df_median_title_age['Age']))
title_age_map
# Out:
# {'Master': 3.5, 'Miss': 21.0, 'Mr': 30.0, 'Mrs': 35.0, 'Other': 48.0}

# %%
filtered_df = df[df['Name'].str.contains('Miss.', case=False, na=False)].dropna(subset=['Age'])
filtered_df
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 2              3         1       3                Heikkinen, Miss. Laina
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 11            12         1       1              Bonnell, Miss. Elizabeth
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                   ...
# 853          854         1       1             Lines, Miss. Mary Conover
# 866          867         1       2          Duran y More, Miss. Asuncion
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 10   female   4.0      1      1           PP 9549  16.7000    G6        S
# 11   female  58.0      0      0            113783  26.5500  C103        S
# 14   female  14.0      0      0            350406   7.8542   NaN        S
# 22   female  15.0      0      0            330923   8.0292   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 853  female  16.0      0      1          PC 17592  39.4000   D28        S
# 866  female  27.0      1      0     SC/PARIS 2149  13.8583   NaN        C
# 875  female  15.0      0      0              2667   7.2250   NaN        C
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
#
#     age_group title
# 2       20-30  Miss
# 10      02-06  Miss
# 11      50-60  Miss
# 14      12-20  Miss
# 22      12-20  Miss
# ..        ...   ...
# 853     12-20  Miss
# 866     20-30  Miss
# 875     12-20  Miss
# 882     20-30  Miss
# 887     12-20  Miss
#
# [146 rows x 14 columns]

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Normalizing data before transforming it into a pytorch tensor

# %%
# Create buckets for Age
def get_age_group_numeric(age):
    if age <= 2:
        return 0.0
    elif age <= 6:
        return 1.0
    elif age <= 12:
        return 2.0
    elif age <= 20:
        return 3.0
    elif age <= 30:
        return 4.0
    elif age <= 40:
        return 5.0
    elif age <= 50:
        return 6.0
    elif age <= 60:
        return 7.0
    elif age <= 70:
        return 8.0
    else:
        return 9.0

# %%
# Normalize input data
# x: pandas dataframe containing the Titanic dataset
def normalize(df):
    # Set Sex=1 for female and Sex=0 for male
    df['Sex'] = df['Sex'].map({'female': 1, 'male': 0})

    # Extract title from 'Name' column
    df['Title'] = df['Name'].apply(get_name_title)

    # Filling missing Age with median age for corresponding title
    df['Age'] = df['Age'].fillna(df.apply(lambda row: title_age_map[row['Title']], axis=1))

    # Creating age buckets
    df['AgeGroup'] = df['Age'].apply(get_age_group_numeric)

    return df

# %%
normalize(df).head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0  30.0      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Cabin Embarked age_group   title   Title  \
# 0         A/5 21171   7.2500   NaN        S     20-30      Mr      Mr
# 1          PC 17599  71.2833   C85        C     30-40     Mrs     Mrs
# 2  STON/O2. 3101282   7.9250   NaN        S     20-30    Miss    Miss
# 3            113803  53.1000  C123        S     30-40     Mrs     Mrs
# 4            373450   8.0500   NaN        S     30-40      Mr      Mr
# 5            330877   8.4583   NaN        Q       NaN      Mr      Mr
# 6             17463  51.8625   E46        S     50-60      Mr      Mr
# 7            349909  21.0750   NaN        S     00-02  Master  Master
# 8            347742  11.1333   NaN        S     20-30     Mrs     Mrs
# 9            237736  30.0708   NaN        C     12-20     Mrs     Mrs
#
#    AgeGroup
# 0       4.0
# 1       5.0
# 2       4.0
# 3       5.0
# 4       5.0
# 5       4.0
# 6       7.0
# 7       0.0
# 8       4.0
# 9       3.0

# %% [markdown]
# ## Load data in Pytorch datasets

# %%
class TitanicDataset(Dataset):
    def __init__(self, csv_file, features_cols, label_col=None):
        """
        Initialize Dataset from CSV file
        """
        df = pd.read_csv(csv_file)
        df = normalize(df)

        self.features_cols = features_cols
        self.label_col = label_col
        self.has_labels = label_col is not None

        # Convert data into pytorch tensors
        self.features = torch.tensor(df[features_cols].values, dtype=torch.float32)
        if self.has_labels:
            self.labels = torch.tensor(df[self.label_col].values, dtype=torch.long)

    def __len__(self):
        """
        Retourne le nombre d'échantillons.
        """
        return len(self.features)

    def __getitem__(self, index):
        """
        Retourne un échantillon (features, label) à l'index donné.
        """
        if self.has_labels:
            return self.features[index], self.labels[index]
        else:
            return self.features[index]


features_cols = ['Sex', 'Pclass', 'AgeGroup']
label_col = 'Survived'

# Use 80% of the dataset to train our model
# Remaning 20% are used to validate the model with unseen data (validation dataset)
train_dataset_length_pct = 0.8
val_dataset_length_pct = 1 - train_dataset_length_pct

dataset = TitanicDataset(CSV_FILE_TRAIN, features_cols, label_col)
train_dataset, val_dataset = random_split(dataset, lengths=[train_dataset_length_pct, val_dataset_length_pct])

# %% [markdown]
# # Model training

# %% [markdown]
# ## Create neural network

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")


# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            #nn.Linear(2, 4),
            #nn.ReLU(),
            nn.Linear(3, 2)
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits


model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=3, out_features=2, bias=True)
#   )
# )

# %%
batch_size = 16
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 8 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# ## Train model

# %%
learning_rate = 1e-3
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(val_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.183602  [   16/  713]
# loss: 1.339632  [  144/  713]
# loss: 1.571720  [  272/  713]
# loss: 0.909505  [  400/  713]
# loss: 1.210307  [  528/  713]
# loss: 0.709368  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.968185
#
# Epoch 2
# -------------------------------
# loss: 0.181893  [   16/  713]
# loss: 1.078459  [  144/  713]
# loss: 1.264430  [  272/  713]
# loss: 0.776662  [  400/  713]
# loss: 0.992247  [  528/  713]
# loss: 0.600158  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.803196
#
# Epoch 3
# -------------------------------
# loss: 0.202380  [   16/  713]
# loss: 0.877194  [  144/  713]
# loss: 1.029282  [  272/  713]
# loss: 0.686704  [  400/  713]
# loss: 0.836792  [  528/  713]
# loss: 0.537700  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.696921
#
# Epoch 4
# -------------------------------
# loss: 0.243619  [   16/  713]
# loss: 0.745209  [  144/  713]
# loss: 0.872928  [  272/  713]
# loss: 0.636829  [  400/  713]
# loss: 0.741606  [  528/  713]
# loss: 0.514050  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.640759
#
# Epoch 5
# -------------------------------
# loss: 0.293974  [   16/  713]
# loss: 0.671822  [  144/  713]
# loss: 0.781221  [  272/  713]
# loss: 0.614155  [  400/  713]
# loss: 0.689972  [  528/  713]
# loss: 0.511915  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.615734
#
# Epoch 6
# -------------------------------
# loss: 0.339806  [   16/  713]
# loss: 0.635358  [  144/  713]
# loss: 0.731086  [  272/  713]
# loss: 0.605204  [  400/  713]
# loss: 0.663391  [  528/  713]
# loss: 0.517055  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.605621
#
# Epoch 7
# -------------------------------
# loss: 0.374233  [   16/  713]
# loss: 0.617723  [  144/  713]
# loss: 0.703921  [  272/  713]
# loss: 0.601662  [  400/  713]
# loss: 0.649438  [  528/  713]
# loss: 0.522549  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.601433
#
# Epoch 8
# -------------------------------
# loss: 0.397086  [   16/  713]
# loss: 0.608673  [  144/  713]
# loss: 0.688700  [  272/  713]
# loss: 0.599805  [  400/  713]
# loss: 0.641563  [  528/  713]
# loss: 0.526338  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.599293
#
# Epoch 9
# -------------------------------
# loss: 0.411028  [   16/  713]
# loss: 0.603418  [  144/  713]
# loss: 0.679675  [  272/  713]
# loss: 0.598301  [  400/  713]
# loss: 0.636643  [  528/  713]
# loss: 0.528357  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.597765
#
# Epoch 10
# -------------------------------
# loss: 0.418942  [   16/  713]
# loss: 0.599886  [  144/  713]
# loss: 0.673942  [  272/  713]
# loss: 0.596776  [  400/  713]
# loss: 0.633210  [  528/  713]
# loss: 0.529060  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.596383
#
# Epoch 11
# -------------------------------
# loss: 0.423048  [   16/  713]
# loss: 0.597185  [  144/  713]
# loss: 0.670010  [  272/  713]
# loss: 0.595170  [  400/  713]
# loss: 0.630556  [  528/  713]
# loss: 0.528902  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.595017
#
# Epoch 12
# -------------------------------
# loss: 0.424837  [   16/  713]
# loss: 0.594918  [  144/  713]
# loss: 0.667090  [  272/  713]
# loss: 0.593508  [  400/  713]
# loss: 0.628327  [  528/  713]
# loss: 0.528218  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.593644
#
# Epoch 13
# -------------------------------
# loss: 0.425250  [   16/  713]
# loss: 0.592900  [  144/  713]
# loss: 0.664749  [  272/  713]
# loss: 0.591823  [  400/  713]
# loss: 0.626337  [  528/  713]
# loss: 0.527227  [  656/  713]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.592268
#
# Epoch 14
# -------------------------------
# loss: 0.424859  [   16/  713]
# loss: 0.591038  [  144/  713]
# loss: 0.662749  [  272/  713]
# loss: 0.590141  [  400/  713]
# loss: 0.624485  [  528/  713]
# loss: 0.526064  [  656/  713]
# Test Error:
#  Accuracy: 60.7%, Avg loss: 0.590899
#
# Epoch 15
# -------------------------------
# loss: 0.424004  [   16/  713]
# loss: 0.589283  [  144/  713]
# loss: 0.660950  [  272/  713]
# loss: 0.588477  [  400/  713]
# loss: 0.622714  [  528/  713]
# loss: 0.524811  [  656/  713]
# Test Error:
#  Accuracy: 66.9%, Avg loss: 0.589543
#
# Epoch 16
# -------------------------------
# loss: 0.422887  [   16/  713]
# loss: 0.587608  [  144/  713]
# loss: 0.659276  [  272/  713]
# loss: 0.586841  [  400/  713]
# loss: 0.620994  [  528/  713]
# loss: 0.523517  [  656/  713]
# Test Error:
#  Accuracy: 70.2%, Avg loss: 0.588205
#
# Epoch 17
# -------------------------------
# loss: 0.421627  [   16/  713]
# loss: 0.585996  [  144/  713]
# loss: 0.657679  [  272/  713]
# loss: 0.585239  [  400/  713]
# loss: 0.619306  [  528/  713]
# loss: 0.522209  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.586887
#
# Epoch 18
# -------------------------------
# loss: 0.420290  [   16/  713]
# loss: 0.584439  [  144/  713]
# loss: 0.656133  [  272/  713]
# loss: 0.583672  [  400/  713]
# loss: 0.617640  [  528/  713]
# loss: 0.520904  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.585592
#
# Epoch 19
# -------------------------------
# loss: 0.418919  [   16/  713]
# loss: 0.582930  [  144/  713]
# loss: 0.654623  [  272/  713]
# loss: 0.582142  [  400/  713]
# loss: 0.615990  [  528/  713]
# loss: 0.519611  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.584318
#
# Epoch 20
# -------------------------------
# loss: 0.417535  [   16/  713]
# loss: 0.581464  [  144/  713]
# loss: 0.653139  [  272/  713]
# loss: 0.580648  [  400/  713]
# loss: 0.614352  [  528/  713]
# loss: 0.518333  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.583066
#
# Epoch 21
# -------------------------------
# loss: 0.416152  [   16/  713]
# loss: 0.580039  [  144/  713]
# loss: 0.651674  [  272/  713]
# loss: 0.579190  [  400/  713]
# loss: 0.612724  [  528/  713]
# loss: 0.517075  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.581836
#
# Epoch 22
# -------------------------------
# loss: 0.414777  [   16/  713]
# loss: 0.578652  [  144/  713]
# loss: 0.650227  [  272/  713]
# loss: 0.577767  [  400/  713]
# loss: 0.611105  [  528/  713]
# loss: 0.515837  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.580627
#
# Epoch 23
# -------------------------------
# loss: 0.413415  [   16/  713]
# loss: 0.577300  [  144/  713]
# loss: 0.648793  [  272/  713]
# loss: 0.576378  [  400/  713]
# loss: 0.609494  [  528/  713]
# loss: 0.514620  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.579439
#
# Epoch 24
# -------------------------------
# loss: 0.412069  [   16/  713]
# loss: 0.575983  [  144/  713]
# loss: 0.647373  [  272/  713]
# loss: 0.575022  [  400/  713]
# loss: 0.607891  [  528/  713]
# loss: 0.513423  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.578270
#
# Epoch 25
# -------------------------------
# loss: 0.410738  [   16/  713]
# loss: 0.574699  [  144/  713]
# loss: 0.645964  [  272/  713]
# loss: 0.573698  [  400/  713]
# loss: 0.606295  [  528/  713]
# loss: 0.512246  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.577120
#
# Epoch 26
# -------------------------------
# loss: 0.409423  [   16/  713]
# loss: 0.573446  [  144/  713]
# loss: 0.644566  [  272/  713]
# loss: 0.572405  [  400/  713]
# loss: 0.604707  [  528/  713]
# loss: 0.511089  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.575989
#
# Epoch 27
# -------------------------------
# loss: 0.408125  [   16/  713]
# loss: 0.572223  [  144/  713]
# loss: 0.643179  [  272/  713]
# loss: 0.571142  [  400/  713]
# loss: 0.603125  [  528/  713]
# loss: 0.509951  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.574876
#
# Epoch 28
# -------------------------------
# loss: 0.406844  [   16/  713]
# loss: 0.571029  [  144/  713]
# loss: 0.641802  [  272/  713]
# loss: 0.569907  [  400/  713]
# loss: 0.601550  [  528/  713]
# loss: 0.508831  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.573780
#
# Epoch 29
# -------------------------------
# loss: 0.405579  [   16/  713]
# loss: 0.569863  [  144/  713]
# loss: 0.640435  [  272/  713]
# loss: 0.568701  [  400/  713]
# loss: 0.599981  [  528/  713]
# loss: 0.507730  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.572700
#
# Epoch 30
# -------------------------------
# loss: 0.404330  [   16/  713]
# loss: 0.568723  [  144/  713]
# loss: 0.639077  [  272/  713]
# loss: 0.567522  [  400/  713]
# loss: 0.598420  [  528/  713]
# loss: 0.506646  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.571637
#
# Epoch 31
# -------------------------------
# loss: 0.403096  [   16/  713]
# loss: 0.567608  [  144/  713]
# loss: 0.637727  [  272/  713]
# loss: 0.566368  [  400/  713]
# loss: 0.596865  [  528/  713]
# loss: 0.505579  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.570589
#
# Epoch 32
# -------------------------------
# loss: 0.401878  [   16/  713]
# loss: 0.566518  [  144/  713]
# loss: 0.636387  [  272/  713]
# loss: 0.565240  [  400/  713]
# loss: 0.595317  [  528/  713]
# loss: 0.504528  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.569557
#
# Epoch 33
# -------------------------------
# loss: 0.400674  [   16/  713]
# loss: 0.565452  [  144/  713]
# loss: 0.635055  [  272/  713]
# loss: 0.564137  [  400/  713]
# loss: 0.593775  [  528/  713]
# loss: 0.503493  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.568539
#
# Epoch 34
# -------------------------------
# loss: 0.399485  [   16/  713]
# loss: 0.564408  [  144/  713]
# loss: 0.633732  [  272/  713]
# loss: 0.563057  [  400/  713]
# loss: 0.592240  [  528/  713]
# loss: 0.502473  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.567535
#
# Epoch 35
# -------------------------------
# loss: 0.398311  [   16/  713]
# loss: 0.563387  [  144/  713]
# loss: 0.632417  [  272/  713]
# loss: 0.562001  [  400/  713]
# loss: 0.590712  [  528/  713]
# loss: 0.501469  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.566545
#
# Epoch 36
# -------------------------------
# loss: 0.397150  [   16/  713]
# loss: 0.562386  [  144/  713]
# loss: 0.631109  [  272/  713]
# loss: 0.560966  [  400/  713]
# loss: 0.589190  [  528/  713]
# loss: 0.500479  [  656/  713]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.565569
#
# Epoch 37
# -------------------------------
# loss: 0.396002  [   16/  713]
# loss: 0.561406  [  144/  713]
# loss: 0.629810  [  272/  713]
# loss: 0.559954  [  400/  713]
# loss: 0.587675  [  528/  713]
# loss: 0.499503  [  656/  713]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.564606
#
# Epoch 38
# -------------------------------
# loss: 0.394868  [   16/  713]
# loss: 0.560445  [  144/  713]
# loss: 0.628518  [  272/  713]
# loss: 0.558962  [  400/  713]
# loss: 0.586166  [  528/  713]
# loss: 0.498541  [  656/  713]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.563655
#
# Epoch 39
# -------------------------------
# loss: 0.393747  [   16/  713]
# loss: 0.559504  [  144/  713]
# loss: 0.627234  [  272/  713]
# loss: 0.557990  [  400/  713]
# loss: 0.584664  [  528/  713]
# loss: 0.497592  [  656/  713]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.562717
#
# Epoch 40
# -------------------------------
# loss: 0.392639  [   16/  713]
# loss: 0.558580  [  144/  713]
# loss: 0.625957  [  272/  713]
# loss: 0.557038  [  400/  713]
# loss: 0.583169  [  528/  713]
# loss: 0.496656  [  656/  713]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.561791
#
# Epoch 41
# -------------------------------
# loss: 0.391543  [   16/  713]
# loss: 0.557675  [  144/  713]
# loss: 0.624688  [  272/  713]
# loss: 0.556105  [  400/  713]
# loss: 0.581680  [  528/  713]
# loss: 0.495733  [  656/  713]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.560877
#
# Epoch 42
# -------------------------------
# loss: 0.390459  [   16/  713]
# loss: 0.556786  [  144/  713]
# loss: 0.623426  [  272/  713]
# loss: 0.555190  [  400/  713]
# loss: 0.580198  [  528/  713]
# loss: 0.494823  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.559974
#
# Epoch 43
# -------------------------------
# loss: 0.389387  [   16/  713]
# loss: 0.555914  [  144/  713]
# loss: 0.622171  [  272/  713]
# loss: 0.554294  [  400/  713]
# loss: 0.578722  [  528/  713]
# loss: 0.493924  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.559082
#
# Epoch 44
# -------------------------------
# loss: 0.388327  [   16/  713]
# loss: 0.555058  [  144/  713]
# loss: 0.620923  [  272/  713]
# loss: 0.553414  [  400/  713]
# loss: 0.577254  [  528/  713]
# loss: 0.493037  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.558201
#
# Epoch 45
# -------------------------------
# loss: 0.387278  [   16/  713]
# loss: 0.554217  [  144/  713]
# loss: 0.619682  [  272/  713]
# loss: 0.552552  [  400/  713]
# loss: 0.575792  [  528/  713]
# loss: 0.492161  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.557330
#
# Epoch 46
# -------------------------------
# loss: 0.386240  [   16/  713]
# loss: 0.553392  [  144/  713]
# loss: 0.618448  [  272/  713]
# loss: 0.551706  [  400/  713]
# loss: 0.574336  [  528/  713]
# loss: 0.491297  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.556470
#
# Epoch 47
# -------------------------------
# loss: 0.385214  [   16/  713]
# loss: 0.552581  [  144/  713]
# loss: 0.617221  [  272/  713]
# loss: 0.550876  [  400/  713]
# loss: 0.572888  [  528/  713]
# loss: 0.490443  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.555620
#
# Epoch 48
# -------------------------------
# loss: 0.384198  [   16/  713]
# loss: 0.551784  [  144/  713]
# loss: 0.616001  [  272/  713]
# loss: 0.550061  [  400/  713]
# loss: 0.571446  [  528/  713]
# loss: 0.489600  [  656/  713]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.554780
#
# Epoch 49
# -------------------------------
# loss: 0.383192  [   16/  713]
# loss: 0.551000  [  144/  713]
# loss: 0.614788  [  272/  713]
# loss: 0.549261  [  400/  713]
# loss: 0.570011  [  528/  713]
# loss: 0.488768  [  656/  713]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.553950
#
# Epoch 50
# -------------------------------
# loss: 0.382197  [   16/  713]
# loss: 0.550230  [  144/  713]
# loss: 0.613581  [  272/  713]
# loss: 0.548476  [  400/  713]
# loss: 0.568583  [  528/  713]
# loss: 0.487945  [  656/  713]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.553129
#
# Done!

# %% [markdown]
# ## Save model

# %%
# Serialize the internal state dictionary (containing the model parameters)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"{MODEL_DIR}/model_state_dic_{timestamp}.pth"
torch.save(model.state_dict(), filename)
print(f"Saved PyTorch Model State to {filename}")
# Out:
# Saved PyTorch Model State to ./models/model_state_dic_20250114_135338.pth

# %% [markdown]
# # Analyze model parameters

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[-0.6192, -0.1523, -0.2596],
#         [ 0.1242, -0.4874, -0.2177]], requires_grad=True)
# Parameter containing:
# tensor([0.4296, 0.1953], requires_grad=True)

# %%
# Logits for different entries
for sex, sex_encoded in [('male', 0.0), ('female', 1.0)]:
    for pclass in [1.0, 2.0, 3.0]:
        for age_group, age_group_encoded in [('02-06', 1.0), ('06-12', 2.0), ('20-30', 4.0), ('40-50', 6.0), ('60-70', 8.0)]:
            pred = model(torch.tensor([sex_encoded, pclass, age_group_encoded])).tolist()
            print(f"Sex={sex}, Pclass={pclass}, AgeGroup={age_group} : {pred}")
# Out:
# Sex=male, Pclass=1.0, AgeGroup=02-06 : [0.017722398042678833, -0.5098662376403809]
# Sex=male, Pclass=1.0, AgeGroup=06-12 : [-0.24183091521263123, -0.7276023626327515]
# Sex=male, Pclass=1.0, AgeGroup=20-30 : [-0.7609374523162842, -1.1630744934082031]
# Sex=male, Pclass=1.0, AgeGroup=40-50 : [-1.2800439596176147, -1.5985467433929443]
# Sex=male, Pclass=1.0, AgeGroup=60-70 : [-1.7991505861282349, -2.0340189933776855]
# Sex=male, Pclass=2.0, AgeGroup=02-06 : [-0.1345979869365692, -0.997290313243866]
# Sex=male, Pclass=2.0, AgeGroup=06-12 : [-0.3941513001918793, -1.2150263786315918]
# Sex=male, Pclass=2.0, AgeGroup=20-30 : [-0.9132579565048218, -1.650498628616333]
# Sex=male, Pclass=2.0, AgeGroup=40-50 : [-1.4323643445968628, -2.085970878601074]
# Sex=male, Pclass=2.0, AgeGroup=60-70 : [-1.951470971107483, -2.5214431285858154]
# Sex=male, Pclass=3.0, AgeGroup=02-06 : [-0.28691843152046204, -1.4847145080566406]
# Sex=male, Pclass=3.0, AgeGroup=06-12 : [-0.5464717149734497, -1.7024505138397217]
# Sex=male, Pclass=3.0, AgeGroup=20-30 : [-1.0655783414840698, -2.137922763824463]
# Sex=male, Pclass=3.0, AgeGroup=40-50 : [-1.5846847295761108, -2.573395013809204]
# Sex=male, Pclass=3.0, AgeGroup=60-70 : [-2.1037912368774414, -3.0088672637939453]
# Sex=female, Pclass=1.0, AgeGroup=02-06 : [-0.6015210151672363, -0.3856343626976013]
# Sex=female, Pclass=1.0, AgeGroup=06-12 : [-0.8610743284225464, -0.6033704876899719]
# Sex=female, Pclass=1.0, AgeGroup=20-30 : [-1.380180835723877, -1.0388426780700684]
# Sex=female, Pclass=1.0, AgeGroup=40-50 : [-1.8992873430252075, -1.4743149280548096]
# Sex=female, Pclass=1.0, AgeGroup=60-70 : [-2.418393850326538, -1.9097871780395508]
# Sex=female, Pclass=2.0, AgeGroup=02-06 : [-0.7538414001464844, -0.8730583786964417]
# Sex=female, Pclass=2.0, AgeGroup=06-12 : [-1.0133947134017944, -1.090794563293457]
# Sex=female, Pclass=2.0, AgeGroup=20-30 : [-1.5325013399124146, -1.5262668132781982]
# Sex=female, Pclass=2.0, AgeGroup=40-50 : [-2.051607608795166, -1.9617390632629395]
# Sex=female, Pclass=2.0, AgeGroup=60-70 : [-2.570714235305786, -2.3972113132476807]
# Sex=female, Pclass=3.0, AgeGroup=02-06 : [-0.906161904335022, -1.3604824542999268]
# Sex=female, Pclass=3.0, AgeGroup=06-12 : [-1.1657150983810425, -1.578218698501587]
# Sex=female, Pclass=3.0, AgeGroup=20-30 : [-1.6848217248916626, -2.013690948486328]
# Sex=female, Pclass=3.0, AgeGroup=40-50 : [-2.203927993774414, -2.4491631984710693]
# Sex=female, Pclass=3.0, AgeGroup=60-70 : [-2.723034620285034, -2.8846354484558105]

# %% [markdown]
# # Predictions on test set and submission

# %%
def predict(dataloader, model):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    # Initiliaze empty tensor that will contain our predictions
    pred = torch.tensor([])
    with torch.no_grad():
        for X in dataloader:
            logits = model(X)
            batch_pred = logits.argmax(1)
            pred = torch.cat((pred, batch_pred))
    return pred

# %%
# Write CSV file ready to be submitted to Kaggle
# pred: pytorch tensor (m, 1) with predictions
def write_submission_file(csv_file_test, pred):
    df = pd.read_csv(csv_file_test)
    df['Survived'] = pred.tolist()
    df['Survived'] = df['Survived'].astype(int)
    df = df[['PassengerId', 'Survived']]

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"{DATA_DIR}/tbriot_submission_{timestamp}.csv"
    df.to_csv(filename, index=False)
    print(f"Submission {filename} has been written!")

# %%
features_cols = ['Sex', 'Pclass', 'AgeGroup']
test_batch_size = 64

test_dataset = TitanicDataset(CSV_FILE_TEST, features_cols)
test_dataloader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# Invoke model to get predictions
pred = predict(test_dataloader, model)
# Write predictions to submission file
write_submission_file(CSV_FILE_TEST, pred)
# Out:
# Submission ./data/tbriot_submission_20250114_135428.csv has been written!
