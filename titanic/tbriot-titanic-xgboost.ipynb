# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
from sagemaker import image_uris

# %% [markdown]
# ## Constants

# %%
DATA_DIR = "./data"
MODEL_DIR = "./models"
CSV_FILE_TRAIN = DATA_DIR + "/train.csv"
CSV_FILE_TEST = DATA_DIR + "/test.csv"

# %%
# this line automatically looks for the XGBoost image URI and builds an XGBoost container.
# specify the repo_version depending on your preference.
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.7-1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # this line automatically looks for the XGBoost image URI and builds an XGBoost container.
#       2 # specify the repo_version depending on your preference.
# ----> 3 xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.7-1")
#
# NameError: name 'sagemaker' is not defined
